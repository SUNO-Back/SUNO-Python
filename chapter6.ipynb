# %% [markdown]
# <a href="https://colab.research.google.com/github/SUNO-Back/SUNO-Python/blob/main/chapter6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 변수 : 하나의 값을 저장할 수 있는 공간을 생성하는 것
#
# 변수명을 만들때 컨벤션
# 변수를 표현하는 방법 : 스네이크,카멜
# 변수를 활용해서 다양한 문제 해결
#
# print() f-string = print(f{''}) <- 요렇게 적어야함

# %% [markdown]
# ### 자료형 종류
# 1. int(integer) : 정수 ex. 1, 2, 3, 4, -1, -2, -3, -4
# 2. float(float) : 실수 ex. 1.2, 3.3, 4.5, 4.0
# 3. str(string) : 문자
# 4. bool(bool, boolean) : 진실 또는 거짓, true or false, 1 또는 0.
# 5. list
# 6. tuple
# 7. dict
# 8. set

# %%
#1. int(integer) : 정수 ex. 1, 2, 3, 4, -1, -2, -3, -4
#2. float(float) : 실수 ex. 1.2, 3.3, 4.5, 4.0

9.0 + 2
# Out:
# 11.0

# %%
#box_num에 숫자만 넣자는 약속을 했는데 누군가 한글 표기법으로 숫자를 넣었다.

box_num = "하나"
box_num += 1

print(box_num)

#이러한 문제를 해결하기 위해서는
type(box_num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1198293246.py in <cell line: 0>()
#       2
#       3 box_num = "하나"
# ----> 4 box_num += 1
#       5
#       6 print(box_num)
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(box_num)
# Out:
# str

# %%
#맨위에 써있는 타입코드들을 확인해보자
type(1)
type(1.2)
# Out:
# float

# %%
# 2여야 하려면 형변환(형태변환)

4/2
# Out:
# 2.0

# %% [markdown]
# ###말그대로 형태를 변형한다 : 형변환
# int, float
# int ->float 예) 5->5.0 flotat(5) = 5가 5.0으로 바뀌어서 출력됨

# %%
print(float(5))
print(int(5.0))
# Out:
# 5.0
# 5

# %%
나이 = 10
type(나이)
print(dir(나이))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'is_integer', 'numerator', 'real', 'to_bytes']

# %%
print(나이.bit_length())
print(bin(나이))
# Out:
# 4
# 0b1010

# %% [markdown]
# #메소드/내장함수/함수에 대하여
#
#
# * 함수 : 독립적으로 정의하여 호출할 수 있는 코드블록. 파이썬 내장 함수와 사용자 정의 함수 모두 포함.
# * 내장함수: 파이썬이 기본적으로 제공하는 함수들, 예를들어len(),print(),sum()등이 있다.
# * 메소드 : 객체에 속한 함수. 객체의 상태를 변화시키거나 정보를 얻는 데 사용된다.
#  ex) 리스트의 append(), 문자열의 lower() 등이 메소드입니다.
